# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('/workspaces/Spatio-Temporal-EV-Adoption-Forecasting-Project/data/processed/cleaned_charging_patterns.csv')

# %%
df2=pd.read_csv('/workspaces/Spatio-Temporal-EV-Adoption-Forecasting-Project/data/processed/EV_specs.csv')

# %%
df3=pd.read_csv('/workspaces/Spatio-Temporal-EV-Adoption-Forecasting-Project/data/processed/ev_spatial.csv')

# %% [markdown]
# # Dataset 1st

# %%
df1.head()
# Out:
#     user_id  vehicle_model  battery_capacity_(kwh)  charging_station_id  \
# 0 -1.730739              0                1.623166             1.030207
# 1 -1.728115              2                1.235132             1.287279
# 2 -1.725491              1                0.022525            -0.428847
# 3 -1.722866              2               -1.190081             0.585543
# 4 -1.720242              2               -1.190081            -0.936043
#
#    charging_station_location  charging_start_time  charging_end_time  \
# 0                          1            -1.178850          -1.181028
# 1                          4            -1.178644          -1.180489
# 2                          4            -1.178438          -1.180186
# 3                          1            -1.178232          -1.179787
# 4                          2            -1.178026          -1.179984
#
#    energy_consumed_(kwh)  charging_duration_(hours)  charging_rate_(kw)  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   user_id                                   1320 non-null   float64
#  1   vehicle_model                             1320 non-null   int64
#  2   battery_capacity_(kwh)                    1320 non-null   float64
#  3   charging_station_id                       1320 non-null   float64
#  4   charging_station_location                 1320 non-null   int64
#  5   charging_start_time                       1320 non-null   float64
#  6   charging_end_time                         1320 non-null   float64
#  7   energy_consumed_(kwh)                     1320 non-null   float64
#  8   charging_duration_(hours)                 1320 non-null   float64
#  9   charging_rate_(kw)                        1320 non-null   float64
# ...

# %%
df1.describe()
# Out:
#            user_id  vehicle_model  battery_capacity_(kwh)  \
# count  1320.000000    1320.000000            1.320000e+03
# mean      0.000000       2.036364            1.641784e-16
# std       1.000379       1.421767            1.000379e+00
# min      -1.730739       0.000000           -3.518286e+00
# 25%      -0.865370       1.000000           -6.080303e-01
# 50%       0.000000       2.000000            2.252508e-02
# 75%       0.865370       3.000000            5.075677e-01
# max       1.730739       4.000000            5.746028e+00
#
#        charging_station_id  charging_station_location  charging_start_time  \
# count         1.320000e+03                1320.000000         1.320000e+03
# mean          1.614870e-17                   2.028030        -2.194664e-11
# std           1.000379e+00                   1.387686         1.000379e+00
# min          -1.679466e+00                   0.000000        -1.178850e+00
# ...

# %%
df1.isnull().sum()
# Out:
# user_id                                     0
# vehicle_model                               0
# battery_capacity_(kwh)                      0
# charging_station_id                         0
# charging_station_location                   0
# charging_start_time                         0
# charging_end_time                           0
# energy_consumed_(kwh)                       0
# charging_duration_(hours)                   0
# charging_rate_(kw)                          0
# charging_cost_(usd)                         0
# time_of_day                                 0
# day_of_week                                 0
# state_of_charge_(start_%)                   0
# state_of_charge_(end_%)                     0
# distance_driven_(since_last_charge)_(km)    0
# temperature_(°c)                            0
# vehicle_age_(years)                         0
# charger_type                                0
# user_type                                   0
# dtype: int64
